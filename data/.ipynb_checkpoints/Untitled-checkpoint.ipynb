# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from pylab import rcParams
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from numpy.random import normal, seed
from scipy.stats import norm
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
import math
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Now let's import the data, explore and check for missing values. Standard data preprocessing.

# %%
pwd
# Out:
# 'C:\\Users\\dimit\\Documents\\GitHub\\Time-Series-2---Predicting-air-quality-\\data'

# %%
data = pd.read_csv("AirQualityUCI.csv", sep=';')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# ...

# %%
data.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
data = data.drop(['Unnamed: 15', 'Unnamed: 16'], axis = 1)

# %%
data.dropna(thresh=1)
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1       1314.0    -200.0     13,5
# 9353  04/04/2005  11.00.00    2,4       1163.0    -200.0     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0    -200.0     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0    -200.0      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
data = data.set_index('Date')

# %%
data = data[data.index.notnull()]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9357 entries, 10/03/2004 to 04/04/2005
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Time           9357 non-null   object
#  1   CO(GT)         9357 non-null   object
#  2   PT08.S1(CO)    9357 non-null   float64
#  3   NMHC(GT)       9357 non-null   float64
#  4   C6H6(GT)       9357 non-null   object
#  5   PT08.S2(NMHC)  9357 non-null   float64
#  6   NOx(GT)        9357 non-null   float64
#  7   PT08.S3(NOx)   9357 non-null   float64
#  8   NO2(GT)        9357 non-null   float64
#  9   PT08.S4(NO2)   9357 non-null   float64
#  10  PT08.S5(O3)    9357 non-null   float64
#  11  T              9357 non-null   object
#  12  RH             9357 non-null   object
#  13  AH             9357 non-null   object
# dtypes: float64(8), object(6)
# memory usage: 1.1+ MB

# %%
data.head()
# Out:
#                 Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# Date
# 10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#             NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T  \
# Date
# 10/03/2004    166.0        1056.0    113.0        1692.0       1268.0  13,6
# 10/03/2004    103.0        1174.0     92.0        1559.0        972.0  13,3
# 10/03/2004    131.0        1140.0    114.0        1555.0       1074.0  11,9
# 10/03/2004    172.0        1092.0    122.0        1584.0       1203.0  11,0
# 10/03/2004    131.0        1205.0    116.0        1490.0       1110.0  11,2
#
#               RH      AH
# Date
# ...

# %%
data.tail()
# Out:
#                 Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# Date
# 04/04/2005  10.00.00    3,1       1314.0    -200.0     13,5         1101.0
# 04/04/2005  11.00.00    2,4       1163.0    -200.0     11,4         1027.0
# 04/04/2005  12.00.00    2,4       1142.0    -200.0     12,4         1063.0
# 04/04/2005  13.00.00    2,1       1003.0    -200.0      9,5          961.0
# 04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9         1047.0
#
#             NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T  \
# Date
# 04/04/2005    472.0         539.0    190.0        1374.0       1729.0  21,9
# 04/04/2005    353.0         604.0    179.0        1264.0       1269.0  24,3
# 04/04/2005    293.0         603.0    175.0        1241.0       1092.0  26,9
# 04/04/2005    235.0         702.0    156.0        1041.0        770.0  28,3
# 04/04/2005    265.0         654.0    168.0        1129.0        816.0  28,5
#
#               RH      AH
# Date
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# In some occasions, one might run ffill or bfill to fill the missing values (never mean() in time series), however for this data set its ok to just drop them.

# %% [markdown]
# One last check:

# %%
data.isnull().sum()
# Out:
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %% [markdown]
# So this database shows the meter readings for different gases, and the last three columns are Temp Rel Humidity and Adjusted Humidity

# %% [markdown]
# Let's do some analysis on the temperature.

# %%
data['T'] = data['T'].str.replace(",", ".").astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9357 entries, 10/03/2004 to 04/04/2005
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Time           9357 non-null   object
#  1   CO(GT)         9357 non-null   object
#  2   PT08.S1(CO)    9357 non-null   float64
#  3   NMHC(GT)       9357 non-null   float64
#  4   C6H6(GT)       9357 non-null   object
#  5   PT08.S2(NMHC)  9357 non-null   float64
#  6   NOx(GT)        9357 non-null   float64
#  7   PT08.S3(NOx)   9357 non-null   float64
#  8   NO2(GT)        9357 non-null   float64
#  9   PT08.S4(NO2)   9357 non-null   float64
#  10  PT08.S5(O3)    9357 non-null   float64
#  11  T              9357 non-null   float64
#  12  RH             9357 non-null   object
#  13  AH             9357 non-null   object
# dtypes: float64(9), object(5)
# memory usage: 1.4+ MB

# %%
decomposed = sm.tsa.seasonal_decompose(data['T'], freq=1)

# %%
rcParams['figure.figsize'] = 11, 9

# %%
figure = decomposed.plot()

# %% [markdown]
# ok clearly we have outliers so let's remove those

# %%
data = data[data['T'] > -40 ]

# %%
decomposed = sm.tsa.seasonal_decompose(data['T'], freq=10)

# %%
figure = decomposed.plot()

# %%
data = data.reset_index()

# %%
data.head(5)
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13.6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13.3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11.9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11.0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11.2  59,6
#
#        AH
# 0  0,7578
# 1  0,7255
# 2  0,7502
# 3  0,7867
# ...

# %% [markdown]
# OK so the plots above ugly (xaxis) because of the time intervals. So what I'm going to to instead is to combine Date and Time and then be able to change the frequency from 1h to 5h or 1day. Let's see

# %%
data["Datestamp"] = data["Date"] +' ' + data["Time"]

# %%
data.Datestamp.head(5)
# Out:
# 0    10/03/2004 18.00.00
# 1    10/03/2004 19.00.00
# 2    10/03/2004 20.00.00
# 3    10/03/2004 21.00.00
# 4    10/03/2004 22.00.00
# Name: Datestamp, dtype: object

# %%
from datetime import datetime

# %%
data["Datestamp"] = pd.to_datetime(data['Datestamp'], format='%d/%m/%Y %H.%M.%S')

# %%
data.Datestamp.head(5)
# Out:
# 0   2004-03-10 18:00:00
# 1   2004-03-10 19:00:00
# 2   2004-03-10 20:00:00
# 3   2004-03-10 21:00:00
# 4   2004-03-10 22:00:00
# Name: Datestamp, dtype: datetime64[ns]

# %%
data.head(5)
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13.6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13.3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11.9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11.0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11.2  59,6
#
#        AH           Datestamp
# ...

# %%
data = data.set_index(data["Datestamp"])

# %%
data.head(5)
# Out:
#                            Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT)  \
# Datestamp
# 2004-03-10 18:00:00  10/03/2004  18.00.00    2,6       1360.0     150.0
# 2004-03-10 19:00:00  10/03/2004  19.00.00      2       1292.0     112.0
# 2004-03-10 20:00:00  10/03/2004  20.00.00    2,2       1402.0      88.0
# 2004-03-10 21:00:00  10/03/2004  21.00.00    2,2       1376.0      80.0
# 2004-03-10 22:00:00  10/03/2004  22.00.00    1,6       1272.0      51.0
#
#                     C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  \
# Datestamp
# 2004-03-10 18:00:00     11,9         1046.0    166.0        1056.0    113.0
# 2004-03-10 19:00:00      9,4          955.0    103.0        1174.0     92.0
# 2004-03-10 20:00:00      9,0          939.0    131.0        1140.0    114.0
# 2004-03-10 21:00:00      9,2          948.0    172.0        1092.0    122.0
# 2004-03-10 22:00:00      6,5          836.0    131.0        1205.0    116.0
#
# ...

# %%
data_daily = data.resample("D").mean()

# %%
data_daily.head(5)
# Out:
#             PT08.S1(CO)    NMHC(GT)  PT08.S2(NMHC)     NOx(GT)  PT08.S3(NOx)  \
# Datestamp
# 2004-03-10  1307.800000   73.800000     885.600000  125.200000   1189.600000
# 2004-03-11  1244.166667  104.500000     851.958333  130.041667   1277.250000
# 2004-03-12  1281.666667  141.500000    1008.291667  142.583333   1101.875000
# 2004-03-13  1330.666667  139.250000     992.833333  168.416667    993.208333
# 2004-03-14  1361.125000  116.958333     943.916667  132.166667   1001.291667
#
#                NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)          T
# Datestamp
# 2004-03-10  108.000000   1516.200000  1061.600000  11.720000
# 2004-03-11   87.375000   1522.833333   885.250000   9.837500
# 2004-03-12   89.916667   1627.291667  1084.375000  11.287500
# 2004-03-13  105.583333   1595.791667  1245.916667  12.866667
# 2004-03-14   97.458333   1602.375000  1234.208333  16.012500

# %%
data_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 391 entries, 2004-03-10 to 2005-04-04
# Freq: D
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PT08.S1(CO)    383 non-null    float64
#  1   NMHC(GT)       383 non-null    float64
#  2   PT08.S2(NMHC)  383 non-null    float64
#  3   NOx(GT)        383 non-null    float64
#  4   PT08.S3(NOx)   383 non-null    float64
#  5   NO2(GT)        383 non-null    float64
#  6   PT08.S4(NO2)   383 non-null    float64
#  7   PT08.S5(O3)    383 non-null    float64
#  8   T              383 non-null    float64
# dtypes: float64(9)
# memory usage: 30.5 KB

# %%
data_six_hours = data.resample("4H").mean()

# %%
data_six_hours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2340 entries, 2004-03-10 16:00:00 to 2005-04-04 12:00:00
# Freq: 4H
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PT08.S1(CO)    2259 non-null   float64
#  1   NMHC(GT)       2259 non-null   float64
#  2   PT08.S2(NMHC)  2259 non-null   float64
#  3   NOx(GT)        2259 non-null   float64
#  4   PT08.S3(NOx)   2259 non-null   float64
#  5   NO2(GT)        2259 non-null   float64
#  6   PT08.S4(NO2)   2259 non-null   float64
#  7   PT08.S5(O3)    2259 non-null   float64
#  8   T              2259 non-null   float64
# dtypes: float64(9)
# memory usage: 182.8 KB

# %%
data_six_hours["NOx(GT)"].plot()

# %%
data["RH"] = data["RH"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-0e2dea9ef511> in <module>
# ----> 1 data["RH"] = data["RH"].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
data['RH'] = data['RH'].str.replace(",", ".").astype(float)

# %%
data_four_hours = data.resample("4H").mean()

# %%
data_four_hours.head(5)
# Out:
#                      PT08.S1(CO)  NMHC(GT)  PT08.S2(NMHC)  NOx(GT)  \
# Datestamp
# 2004-03-10 16:00:00      1292.00    112.00         955.00   103.00
# 2004-03-10 20:00:00      1311.75     64.25         868.25   130.75
# 2004-03-11 00:00:00      1106.25     26.25         633.00    -7.75
# 2004-03-11 04:00:00      1068.25     16.75         564.75    42.25
# 2004-03-11 08:00:00      1274.00     67.75         862.25   127.50
#
#                      PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)       T  \
# Datestamp
# 2004-03-10 16:00:00       1174.00    92.00       1559.00       972.00  13.300
# 2004-03-10 20:00:00       1193.50   112.00       1505.50      1084.00  11.325
# 2004-03-11 00:00:00       1549.75     3.25       1294.25       646.00  10.750
# 2004-03-11 04:00:00       1741.00    48.00       1234.75       517.25  10.450
# 2004-03-11 08:00:00       1190.25   100.75       1477.00       915.25  10.650
#
#                          RH
# Datestamp
# 2004-03-10 16:00:00  47.700
# ...

# %%
data_four_hours.RH.plot()

# %%
data_four_hours.RH = data["RH"].resample('4H').mean()

# %%
data_four_hours.RH.head(5)
# Out:
# Datestamp
# 2004-03-10 16:00:00    47.700
# 2004-03-10 20:00:00    58.200
# 2004-03-11 00:00:00    59.175
# 2004-03-11 04:00:00    58.600
# 2004-03-11 08:00:00    58.575
# Freq: 4H, Name: RH, dtype: float64

# %%
data_four_hours.RH.isnull().values.sum()
# Out:
# 81

# %%
data_four_hours = data_four_hours[data_four_hours.columns[~data_four_hours.isnull().all()]]

# %%
data_four_hours.RH.isnull().values.sum()
# Out:
# 81

# %%
data_four_hours = data_four_hours.dropna()

# %%
data_four_hours.RH.isnull().values.sum()
# Out:
# 0

# %%
decomposed = sm.tsa.seasonal_decompose(data_four_hours["RH"],freq=1)
figure = decomposed.plot()

# %%
plot_moving_average(data_four_hours.RH, 3,plot_intervals=True)

# %%
def tsplot(y, lags=None, figsize=(12, 7), syle='bmh'):
    
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    with plt.style.context(style='bmh'):
        fig = plt.figure(figsize=figsize)
        layout = (2,2)
        ts_ax = plt.subplot2grid(layout, (0,0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1,0))
        pacf_ax = plt.subplot2grid(layout, (1,1))
        
        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()
        
tsplot(data_four_hours.RH, lags=30)

# %%
data_four_hours.RH.hist()

# %% [markdown]
# Seems like white noise - no forecasting can be done.

# %% [markdown]
# Lets explore another variable

# %%
data_four_hours.head(5)
# Out:
#                      PT08.S1(CO)  NMHC(GT)  PT08.S2(NMHC)  NOx(GT)  \
# Datestamp
# 2004-03-10 16:00:00      1292.00    112.00         955.00   103.00
# 2004-03-10 20:00:00      1311.75     64.25         868.25   130.75
# 2004-03-11 00:00:00      1106.25     26.25         633.00    -7.75
# 2004-03-11 04:00:00      1068.25     16.75         564.75    42.25
# 2004-03-11 08:00:00      1274.00     67.75         862.25   127.50
#
#                      PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)       T  \
# Datestamp
# 2004-03-10 16:00:00       1174.00    92.00       1559.00       972.00  13.300
# 2004-03-10 20:00:00       1193.50   112.00       1505.50      1084.00  11.325
# 2004-03-11 00:00:00       1549.75     3.25       1294.25       646.00  10.750
# 2004-03-11 04:00:00       1741.00    48.00       1234.75       517.25  10.450
# 2004-03-11 08:00:00       1190.25   100.75       1477.00       915.25  10.650
#
#                          RH
# Datestamp
# 2004-03-10 16:00:00  47.700
# ...

# %%
data_four_hours["T"].plot()

# %%
decomposed = sm.tsa.seasonal_decompose(data_four_hours["T"],freq=1)
figure = decomposed.plot()

# %%
data_four_hours.head(5)
# Out:
#                      PT08.S1(CO)  NMHC(GT)  PT08.S2(NMHC)  NOx(GT)  \
# Datestamp
# 2004-03-10 16:00:00      1292.00    112.00         955.00   103.00
# 2004-03-10 20:00:00      1311.75     64.25         868.25   130.75
# 2004-03-11 00:00:00      1106.25     26.25         633.00    -7.75
# 2004-03-11 04:00:00      1068.25     16.75         564.75    42.25
# 2004-03-11 08:00:00      1274.00     67.75         862.25   127.50
#
#                      PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T  \
# Datestamp
# 2004-03-10 16:00:00       1174.00    92.00       1559.00       972.00  True
# 2004-03-10 20:00:00       1193.50   112.00       1505.50      1084.00  True
# 2004-03-11 00:00:00       1549.75     3.25       1294.25       646.00  True
# 2004-03-11 04:00:00       1741.00    48.00       1234.75       517.25  True
# 2004-03-11 08:00:00       1190.25   100.75       1477.00       915.25  True
#
#                          RH
# Datestamp
# 2004-03-10 16:00:00  47.700
# ...

# %%
data_four_hours = data.resample("4H").mean()

# %%
data_four_hours.head(5)
# Out:
#                      PT08.S1(CO)  NMHC(GT)  PT08.S2(NMHC)  NOx(GT)  \
# Datestamp
# 2004-03-10 16:00:00      1292.00    112.00         955.00   103.00
# 2004-03-10 20:00:00      1311.75     64.25         868.25   130.75
# 2004-03-11 00:00:00      1106.25     26.25         633.00    -7.75
# 2004-03-11 04:00:00      1068.25     16.75         564.75    42.25
# 2004-03-11 08:00:00      1274.00     67.75         862.25   127.50
#
#                      PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)       T  \
# Datestamp
# 2004-03-10 16:00:00       1174.00    92.00       1559.00       972.00  13.300
# 2004-03-10 20:00:00       1193.50   112.00       1505.50      1084.00  11.325
# 2004-03-11 00:00:00       1549.75     3.25       1294.25       646.00  10.750
# 2004-03-11 04:00:00       1741.00    48.00       1234.75       517.25  10.450
# 2004-03-11 08:00:00       1190.25   100.75       1477.00       915.25  10.650
#
#                          RH
# Datestamp
# 2004-03-10 16:00:00  47.700
# ...

# %%
data_four_hours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2340 entries, 2004-03-10 16:00:00 to 2005-04-04 12:00:00
# Freq: 4H
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PT08.S1(CO)    2259 non-null   float64
#  1   NMHC(GT)       2259 non-null   float64
#  2   PT08.S2(NMHC)  2259 non-null   float64
#  3   NOx(GT)        2259 non-null   float64
#  4   PT08.S3(NOx)   2259 non-null   float64
#  5   NO2(GT)        2259 non-null   float64
#  6   PT08.S4(NO2)   2259 non-null   float64
#  7   PT08.S5(O3)    2259 non-null   float64
#  8   T              2259 non-null   float64
#  9   RH             2259 non-null   float64
# dtypes: float64(10)
# memory usage: 201.1 KB

# %%
y = pd.Series(data_four_hours["T"])

# %%
y
# Out:
# Datestamp
# 2004-03-10 16:00:00    13.300
# 2004-03-10 20:00:00    11.325
# 2004-03-11 00:00:00    10.750
# 2004-03-11 04:00:00    10.450
# 2004-03-11 08:00:00    10.650
#                         ...
# 2005-04-03 20:00:00    15.925
# 2005-04-04 00:00:00    12.850
# 2005-04-04 04:00:00    10.350
# 2005-04-04 08:00:00    19.475
# 2005-04-04 12:00:00    27.900
# Freq: 4H, Name: T, Length: 2340, dtype: float64

# %%
y1 = pd.Series(data_four_hours["RH"])

# %%
y1
# Out:
# Datestamp
# 2004-03-10 16:00:00    47.700000
# 2004-03-10 20:00:00    58.200000
# 2004-03-11 00:00:00    59.175000
# 2004-03-11 04:00:00    58.600000
# 2004-03-11 08:00:00    58.575000
#                          ...
# 2005-04-03 20:00:00    47.200000
# 2005-04-04 00:00:00    54.450000
# 2005-04-04 04:00:00    60.225000
# 2005-04-04 08:00:00    34.550000
# 2005-04-04 12:00:00    14.966667
# Freq: 4H, Name: RH, Length: 2340, dtype: float64

# %%
tsplot(y1, lags = 30)
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-176-b45421c0023a> in <module>
# ----> 1 tsplot(y1, lags = 30)
#
# <ipython-input-142-39cf367e4963> in tsplot(y, lags, figsize, syle)
#      12
#      13         y.plot(ax=ts_ax)
# ---> 14         p_value = sm.tsa.stattools.adfuller(y)[1]
#      15         ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
#      16         smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     266         if not regresults:
#     267             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# --> 268                                        maxlag, autolag)
#     269         else:
# ...

# %%
tsplot(y, lags = 30)
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-177-cc2c5895f499> in <module>
# ----> 1 tsplot(y, lags = 30)
#
# <ipython-input-142-39cf367e4963> in tsplot(y, lags, figsize, syle)
#      12
#      13         y.plot(ax=ts_ax)
# ---> 14         p_value = sm.tsa.stattools.adfuller(y)[1]
#      15         ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
#      16         smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     266         if not regresults:
#     267             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# --> 268                                        maxlag, autolag)
#     269         else:
# ...

# %%
y.isnull()
# Out:
# Datestamp
# 2004-03-10 16:00:00    False
# 2004-03-10 20:00:00    False
# 2004-03-11 00:00:00    False
# 2004-03-11 04:00:00    False
# 2004-03-11 08:00:00    False
#                        ...
# 2005-04-03 20:00:00    False
# 2005-04-04 00:00:00    False
# 2005-04-04 04:00:00    False
# 2005-04-04 08:00:00    False
# 2005-04-04 12:00:00    False
# Freq: 4H, Name: T, Length: 2340, dtype: bool

# %%
y.isnull().values.sum()
# Out:
# 81

# %%
data_four_hours = data_four_hours.dropna()

# %%
data_four_hours.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2259 entries, 2004-03-10 16:00:00 to 2005-04-04 12:00:00
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PT08.S1(CO)    2259 non-null   float64
#  1   NMHC(GT)       2259 non-null   float64
#  2   PT08.S2(NMHC)  2259 non-null   float64
#  3   NOx(GT)        2259 non-null   float64
#  4   PT08.S3(NOx)   2259 non-null   float64
#  5   NO2(GT)        2259 non-null   float64
#  6   PT08.S4(NO2)   2259 non-null   float64
#  7   PT08.S5(O3)    2259 non-null   float64
#  8   T              2259 non-null   float64
#  9   RH             2259 non-null   float64
# dtypes: float64(10)
# memory usage: 194.1 KB

# %%
y = pd.Series(data_four_hours["T"])

# %%
y.isnull().values.sum()
# Out:
# 0

# %%
y
# Out:
# Datestamp
# 2004-03-10 16:00:00    13.300
# 2004-03-10 20:00:00    11.325
# 2004-03-11 00:00:00    10.750
# 2004-03-11 04:00:00    10.450
# 2004-03-11 08:00:00    10.650
#                         ...
# 2005-04-03 20:00:00    15.925
# 2005-04-04 00:00:00    12.850
# 2005-04-04 04:00:00    10.350
# 2005-04-04 08:00:00    19.475
# 2005-04-04 12:00:00    27.900
# Name: T, Length: 2259, dtype: float64

# %%
tsplot(y, lags=30)

# %%
y_diff = data_four_hours.T - data_four_hours.T.shift(1)

# %%
data_four_hours = data.resample("4H").mean()

# %%
data_four_hours = data_four_hours.dropna()

# %%
data_four_hours = data.resample("4H").mean()

# %%
data_four_hours["T"]
# Out:
# Datestamp
# 2004-03-10 16:00:00    13.300
# 2004-03-10 20:00:00    11.325
# 2004-03-11 00:00:00    10.750
# 2004-03-11 04:00:00    10.450
# 2004-03-11 08:00:00    10.650
#                         ...
# 2005-04-03 20:00:00    15.925
# 2005-04-04 00:00:00    12.850
# 2005-04-04 04:00:00    10.350
# 2005-04-04 08:00:00    19.475
# 2005-04-04 12:00:00    27.900
# Freq: 4H, Name: T, Length: 2340, dtype: float64

# %%
data_four_hours.T
# Out:
# Datestamp      2004-03-10 16:00:00  2004-03-10 20:00:00  2004-03-11 00:00:00  \
# PT08.S1(CO)                 1292.0             1311.750             1106.250
# NMHC(GT)                     112.0               64.250               26.250
# PT08.S2(NMHC)                955.0              868.250              633.000
# NOx(GT)                      103.0              130.750               -7.750
# PT08.S3(NOx)                1174.0             1193.500             1549.750
# NO2(GT)                       92.0              112.000                3.250
# PT08.S4(NO2)                1559.0             1505.500             1294.250
# PT08.S5(O3)                  972.0             1084.000              646.000
# T                             13.3               11.325               10.750
# RH                            47.7               58.200               59.175
#
# Datestamp      2004-03-11 04:00:00  2004-03-11 08:00:00  2004-03-11 12:00:00  \
# ...

# %%
tsplot(data_four_hours["T"], lags=40)
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-202-af4e5281c688> in <module>
# ----> 1 tsplot(data_four_hours["T"], lags=40)
#
# <ipython-input-142-39cf367e4963> in tsplot(y, lags, figsize, syle)
#      12
#      13         y.plot(ax=ts_ax)
# ---> 14         p_value = sm.tsa.stattools.adfuller(y)[1]
#      15         ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
#      16         smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     266         if not regresults:
#     267             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# --> 268                                        maxlag, autolag)
#     269         else:
# ...

# %%
data_four_hours = data_four_hours.dropna()

# %%
tsplot(data_four_hours["T"], lags=40)

# %%
y_diff = data_four_hours["T"] - data_four_hours["T"].shift(1)

# %%
tsplot(y_diff[1:], lags=40)

# %%
plot_moving_average(y_diff, window = 3, plot_intervals= True)

# %%
# AR(1) MA(1) model:AR parameter = +0.9
rcParams['figure.figsize'] = 16, 12
plt.subplot(4,1,1)
ar1 = np.array([1, -0.9]) # We choose -0.9 as AR parameter is +0.9
ma1 = np.array([1])
AR1 = ArmaProcess(ar1, ma1)
sim1 = AR1.generate_sample(nsample=1000)
plt.title('AR(1) model: AR parameter = +0.9')
plt.plot(sim1)

# AR(1) MA(1) AR parameter = -0.9
plt.subplot(4,1,2)
ar2 = np.array([1, 0.9]) # We choose +0.9 as AR parameter is -0.9
ma2 = np.array([1])
AR2 = ArmaProcess(ar2, ma2)
sim2 = AR2.generate_sample(nsample=1000)
plt.title('AR(1) model: AR parameter = -0.9')
plt.plot(sim2)

# Activate the model in a simulation

model = ARMA(sim1, order=(1,0))
result = model.fit()
print(result.summary())
print("μ={} ,ϕ={}".format(result.params[0],result.params[1]))
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                     ARMA(1, 0)   Log Likelihood               -1429.465
# Method:                       css-mle   S.D. of innovations              1.010
# Date:                Thu, 14 May 2020   AIC                           2864.930
# Time:                        11:20:46   BIC                           2879.653
# Sample:                             0   HQIC                          2870.526
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2150      0.345      0.622      0.534      -0.462       0.892
# ar.L1.y        0.9085      0.013     69.367      0.000       0.883       0.934
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
model = ARMA(sim2, order=(1,0))
result = model.fit()
print(result.summary())
print("μ={} ,ϕ={}".format(result.params[0],result.params[1]))
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                     ARMA(1, 0)   Log Likelihood               -1422.181
# Method:                       css-mle   S.D. of innovations              1.002
# Date:                Thu, 14 May 2020   AIC                           2850.363
# Time:                        11:21:02   BIC                           2865.086
# Sample:                             0   HQIC                          2855.958
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0143      0.016      0.867      0.386      -0.018       0.047
# ar.L1.y       -0.9232      0.012    -76.661      0.000      -0.947      -0.900
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
AR1t3predict = ARMA(data_four_hours["T"].diff().iloc[1:].values, order=(1,0))
t3 = AR1t3predict.fit()
t3.plot_predict(start=500, end=2000)
plt.show()

# %%
rmse = math.sqrt(mean_squared_error(data_four_hours["T"].diff().iloc[500:1000], result.predict(start=500,end=999)))
print("The root mean squared error is {}.".format(rmse))
# Out:
# The root mean squared error is 5.87645712295526.

# %%
result.predict(start=900,end=999).mean()
# Out:
# -0.007511600049003622

# %%
x = data_four_hours["T"].iloc[900:1000].mean()

# %%
(rmse/x)*100
# Out:
# 19.985060400980323

# %% [markdown]
# AR is not a good model. Let's try MA

# %%
real_data_ma_model = ARMA(data_four_hours["T"].diff().iloc[1:].values, order=(0,3))
result = real_data_ma_model.fit()
print(result.summary())
print("μ={} ,θ={}".format(result.params[0],result.params[1]))
result.plot_predict(start=1000, end=1100)
plt.show()
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 2258
# Model:                     ARMA(0, 3)   Log Likelihood               -5450.857
# Method:                       css-mle   S.D. of innovations              2.704
# Date:                Thu, 14 May 2020   AIC                          10911.715
# Time:                        11:31:39   BIC                          10940.326
# Sample:                             0   HQIC                         10922.156
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0021      0.008      0.263      0.792      -0.014       0.018
# ma.L1.y        0.2790      0.020     13.875      0.000       0.240       0.318
# ma.L2.y       -0.6133      0.012    -49.347      0.000      -0.638      -0.589
# ...

# %%
rmse = math.sqrt(mean_squared_error(data_four_hours["T"].diff().iloc[900:1000], result.predict(start=900,end=999)))
print("The root mean squared error is {}.".format(rmse))
# Out:
# The root mean squared error is 4.387397036604381.

# %%
(rmse/x)*100
# Out:
# 14.92096223030473

# %% [markdown]
# Much better. Now lets try ARMA combined

# %%
real_data_ma_model = ARMA(data_four_hours["T"].diff().iloc[1:].values, order=(3,3))
result = real_data_ma_model.fit()
print(result.summary())
print("μ={} ,θ={}".format(result.params[0],result.params[1]))
result.plot_predict(start=1000, end=1100)
plt.show()
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                      y   No. Observations:                 2258
# Model:                     ARMA(3, 3)   Log Likelihood               -4933.035
# Method:                       css-mle   S.D. of innovations              2.149
# Date:                Thu, 14 May 2020   AIC                           9882.069
# Time:                        11:33:31   BIC                           9927.847
# Sample:                             0   HQIC                          9898.775
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.025      0.113      0.910      -0.047       0.053
# ar.L1.y        0.4174      0.079      5.278      0.000       0.262       0.572
# ar.L2.y       -0.3816      0.078     -4.912      0.000      -0.534      -0.229
# ...

# %%
rmse = math.sqrt(mean_squared_error(data_four_hours["T"].diff().iloc[900:1000], result.predict(start=900,end=999)))
print("The root mean squared error is {}.".format(rmse))
# Out:
# The root mean squared error is 4.824819751284109.

# %%
(rmse/x)*100
# Out:
# 16.408579546440077
